# %% [markdown]
# <a href="https://colab.research.google.com/github/unbroken2650/Deep-Learning-From-Scratch/blob/main/Ch1/1_5_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.5 Numpy
import numpy as np
X = np.array([[51, 55], [14, 19], [0, 4]])
X=X.flatten()
print(X[X>15])
# Out:
# [51 55 19]

# %%
# 1.6 matplotlib

import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1) # 0에서 6까지 0.1 간격으로 생성
y = np.sin(x)

# 그래프 그리기
plt.plot(x, y)
plt.show()
